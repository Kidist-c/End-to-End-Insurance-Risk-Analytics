# %% [markdown]
# # A/B Hypothesis Testing
# #### What we Do here:
# * using the custom module load the cleaned Data
# * Select Metrics with custom module
# * Data Segmentation with custom module
# * Statistical Testing with custom module
# * see the Results here

# %%
# import libraries
import pandas as pd
import numpy as np
import sys
sys.path.append("..")

# %% [markdown]
# ##### Import and Use Custom Module For A?B Testing

# %%
# import module
from src.hypothesis_analysis import run_all

# %%
# run the the module
summery=run_all()
summery
# Out:
# d:\FInalProject\End-to-End-Insurance-Risk-Analytics\notebooks\..\src\hypothesis_analysis.py:24: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, parse_dates=[c for c in ["TransactionMonth","VehicleIntroDate"] if c in pd.read_csv(path, nrows=0).columns], dtype={"PostalCode": str})
# === TASK 3 SUMMARY ===
# Province frequency chi2: {'chi2': 104.19088107029361, 'p': 5.925510718204678e-19, 'dof': 8}
# Province severity kruskal: {'stat': 106.09273218457658, 'p': 2.4146571363417815e-19}
# Zipcode overall frequency chi2: {'chi2': 1454.4676095505502, 'p': 3.152172246339058e-30, 'dof': 887}
# Gender frequency chi2: {'chi2': 7.255926312995721, 'p': 0.026570248768437145, 'dof': 2}
# Gender severity: {'stat': 524.5, 'p': 0.22351273500106295, 'cohen_d': -0.12005124183791252}
# Gender margin: {'stat': -0.2513525622000845, 'p': 0.8015464193501283, 'cohen_d': -0.002754307101570186}
#
# ...

# %% [markdown]
# #### Inspect saved results (very important for reporting)

# %%
zip_pairwise=pd.read_csv("../data/results/task3/zip_pairwise_top.csv")
zip_pairwise.head()
# Out:
#    zip_a  zip_b     n_a    n_b  count_a  count_b    prop_a    prop_b  \
# 0   2000    122  133498  49171      486      210  0.003641  0.004271
# 1   2000   7784  133498  28585      486       50  0.003641  0.001749
# 2   2000    299  133498  25546      486       67  0.003641  0.002623
# 3   2000   7405  133498  18518      486       29  0.003641  0.001566
# 4   2000    458  133498  13775      486       32  0.003641  0.002323
#
#    prop_diff  prop_z_stat  ...                                      prop_ci_a  \
# 0  -0.000630    -1.939401  ...  [0.0033314034718709426, 0.003978169550922884]
# 1   0.001891     5.054891  ...  [0.0033314034718709426, 0.003978169550922884]
# 2   0.001018     2.531910  ...  [0.0033314034718709426, 0.003978169550922884]
# 3   0.002074     4.552739  ...  [0.0033314034718709426, 0.003978169550922884]
# 4   0.001317     2.486676  ...  [0.0033314034718709426, 0.003978169550922884]
#
#                                         prop_ci_b sev_mw_stat     sev_p  \
# ...

# %%
gender_claim=pd.read_csv("../data/results/task3/gender_hasclaim_ct.csv")
gender_claim.head()
# Out:
#           Gender       0     1
# 0         Female    6741    14
# 1           Male   42723    94
# 2  Not specified  938324  2666
